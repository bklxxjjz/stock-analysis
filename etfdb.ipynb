# %% [markdown]
# # Find out the ETFs that a given stock belongs to

# %%
import requests
import json
import re
import time
import random
import html

import pandas as pd
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
def getLandingPage(ticker: str):
    url = f"https://etfdb.com/stock/{ticker}/"

    payload={}
    headers = {}

    response = requests.get(url, headers=headers, data=payload)

    return response

def getId(ticker: str):
    landingPageResponse = getLandingPage(ticker)
    by_stock = re.findall('{"by_stock":\d*}', landingPageResponse.text)
    id = re.findall('\d+', by_stock[0])[0]
    return id

def getExposures(ticker: str):
    id = getId(ticker)
    
    rows = []

    total = float('inf')
    print(f"Retrieving exposures for {ticker}")

    while len(rows) < total:
        url = f'https://etfdb.com/data_set/?tm=40274&cond={{"by_stock":{id}}}&no_null_sort=&count_by_id=true&sort=weighting&order=desc&offset={len(rows)}'

        payload={}
        headers = {}
        response = requests.get(url, headers=headers, data=payload)
        if response.status_code == 200:
            payload = json.loads(response.text)
            
            payload_total = payload['total']
            payload_rows = payload['rows']
        
        total = payload_total
        rows.extend(payload_rows)
        # print(f'Retrieved {len(rows)} rows...', end='\r')
        print('.', end='')

        timeWait = random.randint(5,10)
        time.sleep(timeWait)
    
    print('Done!')
    return rows

# %%
ticker = 'WM'

# %%
exposure_rows = getExposures(ticker)
# Out:
# Retrieving exposures for WM
# .Done!

# %%
exposures = []
for row in exposure_rows:
    e = {}

    e['symbol'] = re.sub('<.*?>', '', html.unescape(row['symbol']))
    e['name'] = re.sub('<.*?>', '', html.unescape(row['sather_etfs.name']))
    e['etf_category'] = re.sub('<.*?>', '', html.unescape(row['etf_category']))
    e['expense_ratio'] = row['expense_ratio']
    e['weighting'] = row['weighting']

    exposures.append(e)

# %%
# for row in exposure_rows:
#     print(row)

# %%
exposures_df = pd.DataFrame.from_dict(exposures)

# %%
exposures_df
# Out:
#    symbol                                               name  \
# 0     EVX          VanEck Vectors Environmental Services ETF
# 1    CCOR                               Core Alternative ETF
# 2    HUSV  First Trust Horizon Managed Volatility Domesti...
# 3    VTRN            VictoryShares Top Veteran Employers ETF
# 4    VETS            Pacer Military Times Best Employers ETF
# 5    AUSF                  Global X Adaptive U.S. Factor ETF
# 6    TPHD               Timothy Plan High Dividend Stock ETF
# 7    USMV                iShares MSCI USA Min Vol Factor ETF
# 8    ACWV             iShares MSCI Global Min Vol Factor ETF
# 9    LGLV    SPDR SSGA US Large Cap Low Volatility Index ETF
# 10   XRLV  Invesco S&P 500® ex-Rate Sensitive Low Volatil...
# 11   VFLQ                 Vanguard U.S. Liquidity Factor ETF
# 12   TPLC  Timothy Plan Fund Timothy Plan US Large/Mid Ca...
# 13    CFO   VictoryShares US 500 Enhanced Volatility Wtd ETF
# 14    CFA            VictoryShares US 500 Volatility Wtd ETF
#
#                  etf_category expense_ratio weighting
# 0        Industrials Equities         0.55%    10.20%
# 1   Large Cap Growth Equities         1.09%     2.89%
# 2    Volatility Hedged Equity         0.70%     1.97%
# 3                         N/A         0.60%     1.97%
# 4    Large Cap Blend Equities         0.60%     1.95%
# 5            All Cap Equities         0.27%     1.63%
# 6            All Cap Equities         0.52%     1.53%
# 7   Large Cap Growth Equities         0.15%     1.47%
# 8    Large Cap Blend Equities         0.20%     1.31%
# 9    Volatility Hedged Equity         0.12%     1.26%
# 10   Volatility Hedged Equity         0.25%     1.19%
# 11           All Cap Equities         0.13%     1.03%
# 12    Mid Cap Growth Equities         0.52%     0.51%
# 13   Large Cap Blend Equities         0.35%     0.37%
# 14   Large Cap Blend Equities         0.35%     0.37%
